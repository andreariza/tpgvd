# %% [markdown]
# <a href="https://colab.research.google.com/github/andreariza/tpgvd/blob/main/tpgvd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importo la librería
import pandas as pd

# %%
#Tomo la base de datos a partir de la url
url = 'https://cdn.buenosaires.gob.ar/datosabiertos/datasets/direccion-general-de-estadisticas-y-censos/encuesta-anual-hogares/encuesta-anual-hogares-2019.csv'

# %%
#Leo el conjunto de datos que voy a utilizar y lo convierto a DataFrame
df_encuesta = pd.read_csv(url, encoding='latin-1')

# %%
#Veo la estructura del conjunto de datos
df_encuesta.shape
# Out:
# (14319, 31)

# %%
#Puedo observar que los datos contienen 14319 filas y 31 columnas. Entonces procedo a ver qué columnas posee.
#Veo las columnas del conjunto de datos
df_encuesta.columns.tolist()
# Out:
# ['id',
#  'nhogar',
#  'miembro',
#  'comuna',
#  'dominio',
#  'edad',
#  'sexo',
#  'parentesco_jefe',
#  'situacion_conyugal',
#  'num_miembro_padre',
#  'num_miembro_madre',
#  'estado_ocupacional',
#  'cat_ocupacional',
#  'calidad_ingresos_lab',
#  'ingreso_total_lab',
#  'calidad_ingresos_no_lab',
#  'ingreso_total_no_lab',
#  'calidad_ingresos_totales',
#  'ingresos_totales',
#  'calidad_ingresos_familiares',
#  'ingresos_familiares',
#  'ingreso_per_capita_familiar',
#  'estado_educativo',
#  'sector_educativo',
#  'nivel_actual',
#  'nivel_max_educativo',
#  'años_escolaridad',
#  'lugar_nacimiento',
#  'afiliacion_salud',
#  'hijos_nacidos_vivos',
#  'cantidad_hijos_nac_vivos']

# %%
#Luego de observar las columnas, quiero observar un ejemplo de este conjunto de datos. Voy a seleccionar las 5 primeras filas.
df_encuesta.head(5)
# Out:
#    id  nhogar  miembro  comuna             dominio  edad   sexo  \
# 0   1       1        1       5  Resto de la Ciudad    18  Mujer
# 1   1       1        2       5  Resto de la Ciudad    18  Mujer
# 2   2       1        1       2  Resto de la Ciudad    18  Varon
# 3   2       1        2       2  Resto de la Ciudad    50  Mujer
# 4   2       1        3       2  Resto de la Ciudad    17  Varon
#
#         parentesco_jefe situacion_conyugal          num_miembro_padre  ...  \
# 0                  Jefe          Soltero/a  Padre no vive en el hogar  ...
# 1      Otro no familiar          Soltero/a  Padre no vive en el hogar  ...
# 2                  Jefe          Soltero/a  Padre no vive en el hogar  ...
# 3  Padre/Madre/Suegro/a            Viudo/a             No corresponde  ...
# 4         Otro familiar          Soltero/a  Padre no vive en el hogar  ...
#
#   ingreso_per_capita_familiar        estado_educativo   sector_educativo  \
# 0                        9000                  Asiste    Estatal/publico
# 1                        9000                  Asiste    Estatal/publico
# 2                       33333                  Asiste  Privado religioso
# 3                       33333  No asiste pero asistió     No corresponde
# 4                       33333                  Asiste  Privado religioso
#
#              nivel_actual        nivel_max_educativo años_escolaridad  \
# 0           Universitario  Otras escuelas especiales               12
# 1           Universitario  Otras escuelas especiales               12
# 2           Universitario  Otras escuelas especiales               12
# 3          No corresponde     Secundario/medio comun               17
# 4  Secundario/medio comun          EGB (1° a 9° año)               10
#
#    lugar_nacimiento                                   afiliacion_salud  \
# 0   PBA excepto GBA                                   Solo obra social
# 1    Otra provincia  Solo plan de medicina prepaga por contratación...
# 2              CABA  Solo plan de medicina prepaga por contratación...
# 3              CABA                       Solo prepaga o mutual via OS
# 4              CABA  Solo plan de medicina prepaga por contratación...
#
#    hijos_nacidos_vivos cantidad_hijos_nac_vivos
# 0                   No           No corresponde
# 1                   No           No corresponde
# 2                  NaN           No corresponde
# 3                   Si                        2
# 4                  NaN           No corresponde
#
# [5 rows x 31 columns]

# %%
#Me quedo solamente con un subset de este conjunto.
df_encuesta[['edad','comuna','sexo','ingreso_per_capita_familiar','nivel_actual', 'lugar_nacimiento', 'sector_educativo']]
# Out:
#        edad  comuna   sexo  ingreso_per_capita_familiar  \
# 0        18       5  Mujer                         9000
# 1        18       5  Mujer                         9000
# 2        18       2  Varon                        33333
# 3        50       2  Mujer                        33333
# 4        17       2  Varon                        33333
# ...     ...     ...    ...                          ...
# 14314    99      10  Varon                        14250
# 14315    78      10  Mujer                        14250
# 14316    60      10  Mujer                        14250
# 14317    92      10  Mujer                        14250
# 14318   100       2  Mujer                        82000
#
#                  nivel_actual   lugar_nacimiento   sector_educativo
# 0               Universitario    PBA excepto GBA    Estatal/publico
# 1               Universitario     Otra provincia    Estatal/publico
# 2               Universitario               CABA  Privado religioso
# 3              No corresponde               CABA     No corresponde
# 4      Secundario/medio comun               CABA  Privado religioso
# ...                       ...                ...                ...
# 14314          No corresponde  Pais no limitrofe     No corresponde
# 14315          No corresponde        Partido GBA     No corresponde
# 14316          No corresponde               CABA     No corresponde
# 14317          No corresponde               CABA     No corresponde
# 14318          No corresponde               CABA     No corresponde
#
# [14319 rows x 7 columns]

# %%
#Voy a guardar este df en un nuevo df que contenga el subset
df_encuesta_reducida = df_encuesta[['edad','comuna','sexo','ingreso_per_capita_familiar','nivel_actual', 'lugar_nacimiento', 'sector_educativo']]

# %%
#Ahora lo quiero guardar en mi base de datos.

#Para eso, importo la libreria.
import sqlite3

# %%
#Genero mi objeto conexion, que va a crear automaticamente la base de datos.
conexion = sqlite3.connect('datoencuesta.db')

# %%
#Una vez que me conecto, puedo pasarlo como parámetro a la función de Pandas que genera la conexión.
df_encuesta_reducida.to_sql('encuesta',con=conexion,if_exists='replace')
# Out:
# 14319

# %%
#Actualizo la ejecución
conexion.commit()

# %%
#Cierro la conexión
conexion.close()

# %%
#Vuelvo a escribir la conexión
conexion = sqlite3.connect('datoencuesta.db')

# %%
cursor = conexion.cursor()

# Consulta SQL para obtener información sobre las columnas de la tabla
consulta = f"PRAGMA table_info(encuesta);"
cursor.execute(consulta)
resultados = cursor.fetchall()

# Chequeamos el tipo de datos que contiene cada columna
for columna in resultados:
    nombre_columna = columna[1]
    tipo_columna = columna[2]
    print(f"Columna: {nombre_columna}, Tipo: {tipo_columna}")
# Out:
# Columna: index, Tipo: INTEGER
# Columna: edad, Tipo: INTEGER
# Columna: comuna, Tipo: INTEGER
# Columna: sexo, Tipo: TEXT
# Columna: ingreso_per_capita_familiar, Tipo: INTEGER
# Columna: nivel_actual, Tipo: TEXT
# Columna: lugar_nacimiento, Tipo: TEXT
# Columna: sector_educativo, Tipo: TEXT

# %%
#Query de consulta
query_consulta = 'SELECT * FROM encuesta;'

# %%
#Ahora voy a generar un cursor para poder navegar la base
cursor = conexion.cursor()

# %%
#Ejecuto la query
cursor.execute(query_consulta)

# %%
#Veo el resultado y guardo el resultado
resultado = cursor.fetchall()

# %%
#Este resultado, lo puedo pasar a un dataframe
df_resultado = pd.DataFrame(resultado,columns=['id', 'edad','comuna','sexo','ingreso_per_capita_familiar','nivel_actual', 'lugar_nacimiento', 'sector_educativo'])

# %%
#Veo el resultado
df_resultado
# Out:
#           id  edad  comuna   sexo  ingreso_per_capita_familiar  \
# 0          0    18       5  Mujer                         9000
# 1          1    18       5  Mujer                         9000
# 2          2    18       2  Varon                        33333
# 3          3    50       2  Mujer                        33333
# 4          4    17       2  Varon                        33333
# ...      ...   ...     ...    ...                          ...
# 14314  14314    99      10  Varon                        14250
# 14315  14315    78      10  Mujer                        14250
# 14316  14316    60      10  Mujer                        14250
# 14317  14317    92      10  Mujer                        14250
# 14318  14318   100       2  Mujer                        82000
#
#                  nivel_actual   lugar_nacimiento   sector_educativo
# 0               Universitario    PBA excepto GBA    Estatal/publico
# 1               Universitario     Otra provincia    Estatal/publico
# 2               Universitario               CABA  Privado religioso
# 3              No corresponde               CABA     No corresponde
# 4      Secundario/medio comun               CABA  Privado religioso
# ...                       ...                ...                ...
# 14314          No corresponde  Pais no limitrofe     No corresponde
# 14315          No corresponde        Partido GBA     No corresponde
# 14316          No corresponde               CABA     No corresponde
# 14317          No corresponde               CABA     No corresponde
# 14318          No corresponde               CABA     No corresponde
#
# [14319 rows x 8 columns]

# %%
#Vamos a realizar una primera consulta que nos permita explorar los datos y vamos a ordenarlo según columnas
query_consulta_2 = '''SELECT * FROM encuesta ORDER BY comuna LIMIT 10;'''

# %%
#Ejecuto la query
cursor.execute(query_consulta_2)

# %%
#Le consulto el resultado
resultado = cursor.fetchall()

# %%
#Veo el resultado
pd.DataFrame(resultado)
# Out:
#     0   1  2      3      4               5                  6  \
# 0  18  19  1  Varon   9800   Universitario               CABA
# 1  19  20  1  Varon   9800   Universitario     Otra provincia
# 2  20  19  1  Varon   9800   Universitario     Otra provincia
# 3  21  19  1  Mujer  30000   Universitario     Otra provincia
# 4  22  19  1  Mujer   5008  No corresponde               CABA
# 5  23   1  1  Varon   5008  No corresponde               CABA
# 6  25  19  1  Mujer      0  No corresponde               CABA
# 7  26  25  1  Varon      0  No corresponde  Pais no limitrofe
# 8  27   1  1  Mujer      0  No corresponde    PBA excepto GBA
# 9  31  19  1  Varon  13000  No corresponde               CABA
#
#                       7
# 0     Privado religioso
# 1       Estatal/publico
# 2     Privado religioso
# 3  Privado no religioso
# 4        No corresponde
# 5        No corresponde
# 6        No corresponde
# 7        No corresponde
# 8        No corresponde
# 9        No corresponde

# %%
#Como es un loop, puedo escribirlo como tal
for fila in resultado:
    print(fila)
# Out:
# (18, 19, 1, 'Varon', 9800, 'Universitario', 'CABA', 'Privado religioso')
# (19, 20, 1, 'Varon', 9800, 'Universitario', 'Otra provincia', 'Estatal/publico')
# (20, 19, 1, 'Varon', 9800, 'Universitario', 'Otra provincia', 'Privado religioso')
# (21, 19, 1, 'Mujer', 30000, 'Universitario', 'Otra provincia', 'Privado no religioso')
# (22, 19, 1, 'Mujer', 5008, 'No corresponde', 'CABA', 'No corresponde')
# (23, 1, 1, 'Varon', 5008, 'No corresponde', 'CABA', 'No corresponde')
# (25, 19, 1, 'Mujer', 0, 'No corresponde', 'CABA', 'No corresponde')
# (26, 25, 1, 'Varon', 0, 'No corresponde', 'Pais no limitrofe', 'No corresponde')
# (27, 1, 1, 'Mujer', 0, 'No corresponde', 'PBA excepto GBA', 'No corresponde')
# (31, 19, 1, 'Varon', 13000, 'No corresponde', 'CABA', 'No corresponde')

# %%
query_consulta_3 = '''SELECT * FROM encuesta WHERE edad>60 ORDER BY edad ASC LIMIT 10;'''

# %%
cursor.execute(query_consulta_3)

# %%
resultado = cursor.fetchall()
pd.DataFrame(resultado)
# Out:
#       0   1  2      3      4               5                  6  \
# 0    88  61  7  Mujer  13000  No corresponde     Otra provincia
# 1   994  61  7  Mujer  35500  No corresponde        Partido GBA
# 2  1249  61  3  Mujer  23667  No corresponde  Pais no limitrofe
# 3  1558  61  4  Mujer  13200  No corresponde  Pais no limitrofe
# 4  5440  61  4  Mujer  11063  No corresponde     Otra provincia
# 5  5441  61  4  Varon  11063  No corresponde     Otra provincia
# 6  7348  61  3  Varon  26667  No corresponde        Partido GBA
# 7  7494  61  4  Varon   6800  No corresponde     Pais limitrofe
# 8  7701  61  1  Varon  46250  No corresponde  Pais no limitrofe
# 9  8129  61  3  Varon  17000  No corresponde     Otra provincia
#
#                 7
# 0  No corresponde
# 1  No corresponde
# 2  No corresponde
# 3  No corresponde
# 4  No corresponde
# 5  No corresponde
# 6  No corresponde
# 7  No corresponde
# 8  No corresponde
# 9  No corresponde

# %%
#Cierro la conexión
conexion.close()
